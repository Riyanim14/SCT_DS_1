# %% [markdown]
# # 🗂️ Task 1 – World Population Visualization

# %%
# 1. Import required libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 2. Load dataset
file_path = "API_SP.POP.TOTL_DS2_en_csv_v2_382887.csv"
data = pd.read_csv(file_path, skiprows=4)

# %%
# 3. Inspect columns
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')

# %%
# 4. Drop missing countries & extract 2022 population
data = data.dropna(subset=["Country Name"])
population_2022 = data[["Country Name", "2022"]].dropna()

# %%
# 5. Top 20 most populous countries
top20 = population_2022.sort_values(by="2022", ascending=False).head(20)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Optional for consistent styling
sns.set_theme(style="whitegrid")

# 6. Improved Plotting
plt.figure(figsize=(14, 6))

# Generate a color gradient using seaborn's color_palette
colors = sns.color_palette("coolwarm", len(top20))

bars = plt.bar(top20["Country Name"], top20["2022"], color=colors)

# Rotate labels & enhance aesthetics
plt.xticks(rotation=75, fontsize=10)
plt.yticks(fontsize=10)
plt.title("Top 20 Countries by Population (2022)", fontsize=16, weight='bold', pad=15)
plt.xlabel("Country", fontsize=12)
plt.ylabel("Population", fontsize=12)

# Add population values on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 1e7,
             f'{int(yval):,}', ha='center', va='bottom', fontsize=9, rotation=90)

plt.tight_layout()
plt.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.7)
plt.show()
